# %% [markdown]
# # ***DMW Lab 2***
# https://colab.research.google.com/drive/1hkq8M2Fc05HUNPlAq28cc12A1IZPHfE0?usp=sharing

# %% [markdown]
# ## **Loading Data**

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
 
data = pd.read_csv("Iris.csv") 
   
print (data.head(10))
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %% [markdown]
# ## **Scatter Plot**

# %%
colours = {'Iris-setosa':'red', 'Iris-versicolor':'yellow', 'Iris-virginica':'blue'}
for i in range(len(iris['SepalLengthCm'])):
  plt.scatter(iris['PetalLengthCm'][i],iris['PetalWidthCm'][i], color = colours[iris['Species'][i]])
plt.title('Iris')
plt.xlabel('petal length')
plt.ylabel('petal width')
plt.grid(True)
plt.show()

# %% [markdown]
# ## **Bar Plot**

# %%
a= iris['Species'].value_counts()
species = a.index
count = a.values
plt.bar(species,count,color = 'lightgreen')
plt.xlabel('species')
plt.ylabel('count')
plt.show()

# %% [markdown]
# ## **Pie Chart**

# %%
a= iris['Species'].value_counts()
species = a.index
count = a.values
colors= ['lightblue','lightgreen','gold']
explode = (0,0.0,0.0)
plt.pie(count, labels=species,shadow=True,
        colors=colors,explode = explode, autopct='%1.1f%%')
# plt.xlabel('species')
plt.axis('equal')
plt.show()

# %% [markdown]
# ## **Box Plot**

# %%
length_width = iris[['PetalLengthCm','PetalWidthCm','SepalLengthCm','SepalWidthCm']] #excluding species column
length_width.boxplot()
plt.xlabel('Flower measurements')
plt.ylabel('values')
plt.title("Iris dataset analysis")
plt.show()

# %% [markdown]
# ## **Histogram**

# %%
plt.figure(figsize = (10, 7)) 
x = data["SepalLengthCm"] 
  
plt.hist(x, bins = 20, color = "blue") 
plt.title("Sepal Length in cm") 
plt.xlabel("Sepal_Length_cm") 
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ## **Line Plot**

# %%
import seaborn as sns
sns.set_style('darkgrid')
sns.lineplot(data=iris.drop(['Species','Id'], axis=1))
plt.show()
